# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/Reviews.tsv', sep='\t')
from nltk.corpus import stopwords

# %%
data.tail(10)
# Out:
#                                                 Review  Liked
# 990  The refried beans that came with my meal were ...      0
# 991         Spend your money and time some place else.      0
# 992  A lady at the table next to us found a live gr...      0
# 993            the presentation of the food was awful.      0
# 994           I can't tell you how disappointed I was.      0
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.describe()
# Out:
#             Liked
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# corpus = []
#print(stopwords.words("english"))
v=set(stopwords.words("english"))
# w={'not','no','ain', 'aren', "don't","aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"}
import re
bag = []
for i in range(0, 1000):
  review = re.sub('[^a-zA-Z]', ' ', data['Review'][i])
  review = review.lower()
  review = review.split()
  from nltk.stem import PorterStemmer

  # lm = WordNetLemmatizer()
  lm = PorterStemmer()
  review = [lm.stem(word) for word in review if not word in set(v)]
  review = ' '.join(review)
  bag.append(review)

# %%
print(bag)
# Out:
# ['wow love place', 'crust good', 'tasti textur nasti', 'stop late may bank holiday rick steve recommend love', 'select menu great price', 'get angri want damn pho', 'honeslti tast fresh', 'potato like rubber could tell made ahead time kept warmer', 'fri great', 'great touch', 'servic prompt', 'would go back', 'cashier care ever say still end wayyy overpr', 'tri cape cod ravoli chicken cranberri mmmm', 'disgust pretti sure human hair', 'shock sign indic cash', 'highli recommend', 'waitress littl slow servic', 'place worth time let alon vega', 'like', 'burritto blah', 'food amaz', 'servic also cute', 'could care less interior beauti', 'perform', 'right red velvet cake ohhh stuff good', 'never brought salad ask', 'hole wall great mexican street taco friendli staff', 'took hour get food tabl restaur food luke warm sever run around like total overwhelm', 'worst salmon sashimi', 'also combo like burger fri beer decent deal', 'like final blow', 'found place accid could happier', 'seem like 
# ...

# %%
print(v)
# Out:
# {"i'll", 'some', "they'd", 'now', 'where', "he's", "shouldn't", "couldn't", 'yourselves', "hasn't", 'all', 'during', "he'd", "she'll", 'mustn', 'being', 'mightn', 'until', 'any', 'other', 'needn', "we'll", 'of', 'through', 'an', 's', 'yours', 'ma', 'few', 'its', 'over', "she's", 'don', 'them', 'had', 'then', 'why', 'when', "i've", 'those', 'so', 'there', 'd', 'their', 'further', 'am', 'before', "didn't", 'himself', "mustn't", 'didn', 'can', 'theirs', 'your', 'm', 'only', 'him', 'out', "you'd", "weren't", 'and', 've', 'we', 'themselves', "wouldn't", "doesn't", 'shouldn', "should've", 'very', 'ours', 'll', 'does', 'isn', "won't", 'myself', 'wouldn', "that'll", "you'll", "it'd", 'should', 'under', "we'd", 'because', 'below', 'shan', 'a', 'but', 'my', 'were', 'whom', 'he', "they'll", 'what', 'own', "it'll", "needn't", 'which', 'just', 'weren', "we're", 'from', 'on', 'if', 'both', 'i', 'her', 'as', 'have', 'o', 're', 'was', 'hers', "they've", 'by', 'too', 'aren', 'this', "it's", 'herself'
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1600)
X = cv.fit_transform(bag).toarray()
y = data['Liked']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
new_review = 'good food'
new_review = re.sub('[^a-zA-Z]', ' ', new_review)
new_review = new_review.lower()
new_review = new_review.split()
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
new_review = [ps.stem(word) for word in new_review if not word in set(all_stopwords)]
new_review = ' '.join(new_review)
new_corpus = [new_review]
new_X_test = cv.transform(new_corpus).toarray()
new_y_pred = classifier.predict(new_X_test)
print(new_y_pred)
# Out:
# [1]

# %%
from sklearn.model_selection import GridSearchCV #GridSearchCV is for parameter tuning
from sklearn.ensemble import RandomForestClassifier
cls=RandomForestClassifier()
n_estimators=[25,50,75,100,125,150,175,200] #number of decision trees in the forest, default = 100
criterion=['gini','entropy'] #criteria for choosing nodes default = 'gini'
max_depth=[3,5,10] #maximum number of nodes in a tree default = None (it will go till all possible nodes)
parameters={'n_estimators': n_estimators,'criterion':criterion,'max_depth':max_depth} #this will undergo 8*2*3 = 48 iterations
RFC_cls = GridSearchCV(cls, parameters)
RFC_cls.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 125, 150, 175, 200]})
